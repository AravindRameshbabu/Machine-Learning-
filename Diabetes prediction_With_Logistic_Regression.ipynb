# %%
## Importing the important libraries to proceed

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize']=(16,10)
# %matplotlib inline

# %%
## Importing the data 
data = pd.read_csv('diabetes_dataset.csv')

# %% [raw]
# ##### Data Description
#
# Age: The age of the individual (18-90 years).
#
# Pregnancies: Number of times the patient has been pregnant.
#
# BMI (Body Mass Index): A measure of body fat based on height and weight (kg/m²).
#
# Glucose: Blood glucose concentration (mg/dL), a key diabetes indicator.
#
# BloodPressure: Systolic blood pressure (mmHg), higher levels may indicate hypertension.
#
# HbA1c: Hemoglobin A1c level (%), representing average blood sugar over months.
#
# LDL (Low-Density Lipoprotein): "Bad" cholesterol level (mg/dL).
#
# HDL (High-Density Lipoprotein): "Good" cholesterol level (mg/dL).
#
# Triglycerides: Fat levels in the blood (mg/dL), high values increase diabetes risk.
#
# WaistCircumference: Waist measurement (cm), an indicator of central obesity.
#
# HipCircumference: Hip measurement (cm), used to calculate WHR.
#
# WHR (Waist-to-Hip Ratio): Waist circumference divided by hip circumference.
#
# FamilyHistory: Indicates if the individual has a family history of diabetes (1 = Yes, 0 = No).
#
# DietType: Dietary habits (0 = Unbalanced, 1 = Balanced, 2 = Vegan/Vegetarian).
#
# Hypertension: Presence of high blood pressure (1 = Yes, 0 = No).
#
# MedicationUse: Indicates if the individual is taking medication (1 = Yes, 0 = No).
#
# Outcome: Diabetes diagnosis result (1 = Diabetes, 0 = No Diabetes).
#
# This dataset is useful for exploring the relationships between lifestyle choices, genetic factors, and diabetes risk, providing valuable insights for predictive modeling and health analytics.

# %%
data.head()
# Out:
#    Age  Pregnancies    BMI  Glucose  BloodPressure  HbA1c    LDL   HDL  \
# 0   69            5  28.39    130.1           77.0    5.4  130.4  44.0
# 1   32            1  26.49    116.5           72.0    4.5   87.4  54.2
# 2   89           13  25.34    101.0           82.0    4.9  112.5  56.8
# 3   78           13  29.91    146.0          104.0    5.7   50.7  39.1
# 4   38            8  24.56    103.2           74.0    4.7  102.5  29.1
#
#    Triglycerides  WaistCircumference  HipCircumference   WHR  FamilyHistory  \
# 0           50.0                90.5             107.9  0.84              0
# 1          129.9               113.3              81.4  1.39              0
# 2          177.6                84.7             107.2  0.79              0
# 3          117.0               108.9             110.0  0.99              0
# 4          145.9                84.1              92.8  0.91              0
#
#    DietType  Hypertension  MedicationUse  Outcome
# ...

# %%
data.shape
# Out:
# (9538, 17)

# %%
data.dtypes
# Out:
# Age                     int64
# Pregnancies             int64
# BMI                   float64
# Glucose               float64
# BloodPressure         float64
# HbA1c                 float64
# LDL                   float64
# HDL                   float64
# Triglycerides         float64
# WaistCircumference    float64
# HipCircumference      float64
# WHR                   float64
# FamilyHistory           int64
# DietType                int64
# Hypertension            int64
# MedicationUse           int64
# Outcome                 int64
# dtype: object

# %%
### Lets check for any null values

# %%
data.isna().sum()
# Out:
# Age                   0
# Pregnancies           0
# BMI                   0
# Glucose               0
# BloodPressure         0
# HbA1c                 0
# LDL                   0
# HDL                   0
# Triglycerides         0
# WaistCircumference    0
# HipCircumference      0
# WHR                   0
# FamilyHistory         0
# DietType              0
# Hypertension          0
# MedicationUse         0
# Outcome               0
# dtype: int64

# %%
#### Introduction to the EDA analysis

# %%
data['Age'].nunique()
# Out:
# 72

# %%
data.groupby('Outcome')['DietType'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Outcome'>

# %%
plt.figure(figsize=(10,10))
plt.hexbin(data['Age'],data['Pregnancies'],gridsize=50,cmap='viridis')
plt.colorbar(label='count_in_bin')
plt.xlabel('Age')
plt.ylabel('The times patients got pregnant')
plt.show()

# %%
### here the visualization part on age and other continues variable is messing up so lets create a variable with bins value

# %%
data['Age_bins'] = pd.cut(data['Age'],bins=[20,30,40,50,60,70,80,90],labels=['21-30','31-40','41-50','51-60','61-70','71-80','81-90'])

# %%
data.head()
# Out:
#    Age  Pregnancies    BMI  Glucose  BloodPressure  HbA1c    LDL   HDL  \
# 0   69            5  28.39    130.1           77.0    5.4  130.4  44.0
# 1   32            1  26.49    116.5           72.0    4.5   87.4  54.2
# 2   89           13  25.34    101.0           82.0    4.9  112.5  56.8
# 3   78           13  29.91    146.0          104.0    5.7   50.7  39.1
# 4   38            8  24.56    103.2           74.0    4.7  102.5  29.1
#
#    Triglycerides  WaistCircumference  HipCircumference   WHR  FamilyHistory  \
# 0           50.0                90.5             107.9  0.84              0
# 1          129.9               113.3              81.4  1.39              0
# 2          177.6                84.7             107.2  0.79              0
# 3          117.0               108.9             110.0  0.99              0
# 4          145.9                84.1              92.8  0.91              0
#
#    DietType  Hypertension  MedicationUse  Outcome Age_bins
# ...

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=data,x='Age_bins',y='Pregnancies')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=data,x='Age_bins',y='BMI')
plt.show()

# %% [raw]
# Here we can see lot of outliers which means that the specific age group have the irregular BMI Values

# %%
data.head()
# Out:
#    Age  Pregnancies    BMI  Glucose  BloodPressure  HbA1c    LDL   HDL  \
# 0   69            5  28.39    130.1           77.0    5.4  130.4  44.0
# 1   32            1  26.49    116.5           72.0    4.5   87.4  54.2
# 2   89           13  25.34    101.0           82.0    4.9  112.5  56.8
# 3   78           13  29.91    146.0          104.0    5.7   50.7  39.1
# 4   38            8  24.56    103.2           74.0    4.7  102.5  29.1
#
#    Triglycerides  WaistCircumference  HipCircumference   WHR  FamilyHistory  \
# 0           50.0                90.5             107.9  0.84              0
# 1          129.9               113.3              81.4  1.39              0
# 2          177.6                84.7             107.2  0.79              0
# 3          117.0               108.9             110.0  0.99              0
# 4          145.9                84.1              92.8  0.91              0
#
#    DietType  Hypertension  MedicationUse  Outcome Age_bins
# ...

# %%
### Lets compare the Pregnancies and Glucose and later lets compare it with Age

# %%
### Right

plt.figure(figsize=(10,10))
sns.boxplot(data=data,x='Age_bins',y='Glucose')
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.boxplot(data=data,x='Pregnancies',y='Glucose')
plt.show()

# %%
data.head(2)
# Out:
#    Age  Pregnancies    BMI  Glucose  BloodPressure  HbA1c    LDL   HDL  \
# 0   69            5  28.39    130.1           77.0    5.4  130.4  44.0
# 1   32            1  26.49    116.5           72.0    4.5   87.4  54.2
#
#    Triglycerides  WaistCircumference  HipCircumference   WHR  FamilyHistory  \
# 0           50.0                90.5             107.9  0.84              0
# 1          129.9               113.3              81.4  1.39              0
#
#    DietType  Hypertension  MedicationUse  Outcome Age_bins
# 0         0             0              1        0    61-70
# 1         0             0              0        0    31-40

# %%
### Comparing the Age and hypertension

# %%
plt.figure(figsize=(12,10))
sns.countplot(data=data,x='Hypertension',hue='Age_bins')
plt.title("Age vs Hypertension")
plt.show()

# %%
data['Hypertension'].value_counts()
# Out:
# 0    9528
# 1      10
# Name: Hypertension, dtype: int64

# %%
### Here we see that the hypertension column is inbalance and it might influence the prediction in the wrong way

# %%
data.head()
# Out:
#    Age  Pregnancies    BMI  Glucose  BloodPressure  HbA1c    LDL   HDL  \
# 0   69            5  28.39    130.1           77.0    5.4  130.4  44.0
# 1   32            1  26.49    116.5           72.0    4.5   87.4  54.2
# 2   89           13  25.34    101.0           82.0    4.9  112.5  56.8
# 3   78           13  29.91    146.0          104.0    5.7   50.7  39.1
# 4   38            8  24.56    103.2           74.0    4.7  102.5  29.1
#
#    Triglycerides  WaistCircumference  HipCircumference   WHR  FamilyHistory  \
# 0           50.0                90.5             107.9  0.84              0
# 1          129.9               113.3              81.4  1.39              0
# 2          177.6                84.7             107.2  0.79              0
# 3          117.0               108.9             110.0  0.99              0
# 4          145.9                84.1              92.8  0.91              0
#
#    DietType  Hypertension  MedicationUse  Outcome Age_bins
# ...

# %%
data['FamilyHistory'].value_counts()
# Out:
# 0    6653
# 1    2885
# Name: FamilyHistory, dtype: int64

# %%
### Lets compare the family history column with the outcome column

# %%
data['Outcome'].value_counts()
# Out:
# 0    6256
# 1    3282
# Name: Outcome, dtype: int64

# %%
### Before we move to comparing phase we should fix the imbalance data which is present in our target column

# %%
## Lets visualize the imbalance data

# %%
plt.figure(figsize=(10,12))
data['Outcome'].value_counts().plot.pie(title='Imbalance data',autopct='%.2f')
plt.show()

# %%
## here we are using imblearn to fix the imbalance data 

## Here we have outcome as imbalance data

# %%
data.columns
# Out:
# Index(['Age', 'Pregnancies', 'BMI', 'Glucose', 'BloodPressure', 'HbA1c', 'LDL',
#        'HDL', 'Triglycerides', 'WaistCircumference', 'HipCircumference', 'WHR',
#        'FamilyHistory', 'DietType', 'Hypertension', 'MedicationUse', 'Outcome',
#        'Age_bins'],
#       dtype='object')

# %%
## Outcome

# %%
## Lets handle the imbalance data with imblearn 

## The jupyter notebook has few requistes to proceed with imblearn 

## Sklearn should be above ver1 
## Once the sklearn gets updated the imblearn get activated and you can use imblearn to handle the imbalance data

# %%
import sklearn 
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
import imblearn
print(imblearn.__version__)
# Out:
# 0.12.4

# %%
y = data['Outcome']

# %%
y.value_counts().plot.pie(title='Imbalance data',autopct='%.2f');

# %%
data.columns
# Out:
# Index(['Age', 'Pregnancies', 'BMI', 'Glucose', 'BloodPressure', 'HbA1c', 'LDL',
#        'HDL', 'Triglycerides', 'WaistCircumference', 'HipCircumference', 'WHR',
#        'FamilyHistory', 'DietType', 'Hypertension', 'MedicationUse', 'Outcome',
#        'Age_bins'],
#       dtype='object')

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
## Medicationinuse - Age 

## Outcome  -- Familyhistory

## BMI -- HIP circumference -- Waist circumference 

## Hba1c -- Glucose 

## WHR -- Waist circumference

# %%
## Lets pay attention to the ouliers even though we handle the classification problem here

# %%
### Robust regressor

# %%
from sklearn.preprocessing import RobustScaler

# %%
rob = RobustScaler()

# %%
data
# Out:
#       Age  Pregnancies    BMI  Glucose  BloodPressure  HbA1c    LDL   HDL  \
# 0      69            5  28.39    130.1           77.0    5.4  130.4  44.0
# 1      32            1  26.49    116.5           72.0    4.5   87.4  54.2
# 2      89           13  25.34    101.0           82.0    4.9  112.5  56.8
# 3      78           13  29.91    146.0          104.0    5.7   50.7  39.1
# 4      38            8  24.56    103.2           74.0    4.7  102.5  29.1
# ...   ...          ...    ...      ...            ...    ...    ...   ...
# 9533   32            3  23.00    102.3           62.0    4.1  109.3  47.8
# 9534   74            0  24.29    125.8           93.0    5.3   95.8  66.6
# 9535   75            6  26.10    107.6           75.0    5.0  168.5  62.3
# 9536   52            1  25.88     99.3           96.0    4.6   70.0  48.4
# 9537   33            3  25.61     69.1           65.0    4.0   69.0  59.4
#
#       Triglycerides  WaistCircumference  HipCircumference   WHR  \
# ...

# %%
## lets remove Age_bins and Outcome

# %%
data.drop(['Age_bins'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Age  Pregnancies    BMI  Glucose  BloodPressure  HbA1c    LDL   HDL  \
# 0   69            5  28.39    130.1           77.0    5.4  130.4  44.0
# 1   32            1  26.49    116.5           72.0    4.5   87.4  54.2
# 2   89           13  25.34    101.0           82.0    4.9  112.5  56.8
# 3   78           13  29.91    146.0          104.0    5.7   50.7  39.1
# 4   38            8  24.56    103.2           74.0    4.7  102.5  29.1
#
#    Triglycerides  WaistCircumference  HipCircumference   WHR  FamilyHistory  \
# 0           50.0                90.5             107.9  0.84              0
# 1          129.9               113.3              81.4  1.39              0
# 2          177.6                84.7             107.2  0.79              0
# 3          117.0               108.9             110.0  0.99              0
# 4          145.9                84.1              92.8  0.91              0
#
#    DietType  Hypertension  MedicationUse  Outcome
# ...

# %%
X = data.drop(['Outcome'],axis=1)

# %%
X
# Out:
#       Age  Pregnancies    BMI  Glucose  BloodPressure  HbA1c    LDL   HDL  \
# 0      69            5  28.39    130.1           77.0    5.4  130.4  44.0
# 1      32            1  26.49    116.5           72.0    4.5   87.4  54.2
# 2      89           13  25.34    101.0           82.0    4.9  112.5  56.8
# 3      78           13  29.91    146.0          104.0    5.7   50.7  39.1
# 4      38            8  24.56    103.2           74.0    4.7  102.5  29.1
# ...   ...          ...    ...      ...            ...    ...    ...   ...
# 9533   32            3  23.00    102.3           62.0    4.1  109.3  47.8
# 9534   74            0  24.29    125.8           93.0    5.3   95.8  66.6
# 9535   75            6  26.10    107.6           75.0    5.0  168.5  62.3
# 9536   52            1  25.88     99.3           96.0    4.6   70.0  48.4
# 9537   33            3  25.61     69.1           65.0    4.0   69.0  59.4
#
#       Triglycerides  WaistCircumference  HipCircumference   WHR  \
# ...

# %%
y = data['Outcome']

# %%
### Lets handle the imbalace data with imblearn

# %%
import imblearn

# %%
from imblearn.over_sampling import RandomOverSampler
random = RandomOverSampler()

# %%
X_random_sample , y_random_sample = random.fit_resample(X,y)
# Out:
# C:\Users\aravi\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\aravi\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(

# %%
print(f'Shapeof_X_sample : ', X_random_sample.shape)
print(' '*20)
print('*'*20)
print(' '*20)
print(f'Shapeof_Y_Sample : ', y_random_sample.shape)
# Out:
# Shapeof_X_sample :  (12512, 16)
#
# ********************
#
# Shapeof_Y_Sample :  (12512,)

# %%
### Lets check the outcome's value counts 

## After 

plt.figure(figsize=(12,10))
y_random_sample.value_counts().plot.pie(title='Outcome attribute after imblearn random_over_Sampler',autopct='%.2f' );
plt.show()

# %%
## Before 

plt.figure(figsize=(12,10))
data['Outcome'].value_counts().plot.pie(title='Outcome attribute before handling the imbalance data',autopct='%.2f')
plt.show()

# %%
## Lets split the data into train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_random_sample,y_random_sample,test_size=0.2,random_state=42)

# %%
### Lets standarize the data with standard scaler

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()

# %%
X_train = std.fit_transform(X_train)
X_test = std.transform(X_test)

# %%
### Lets print out the shape of our data

# %%
print(f'Shape of X_train : ',X_train.shape)
print(' '*20)
print('*'*20)
print(f'Shape of X_test : ',X_test.shape)
print(' '*20)
print('*'*20)
print(f'Shape of y_train :',y_train.shape)
print(' '*20)
print('*'*20)
print(f'Shape of y_test : ',y_test.shape)
# Out:
# Shape of X_train :  (10009, 16)
#
# ********************
# Shape of X_test :  (2503, 16)
#
# ********************
# Shape of y_train : (10009,)
#
# ********************
# Shape of y_test :  (2503,)

# %%
### Modelling the data

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
Log = LogisticRegression()

# %%
Log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### Prediction Part

# %%
Log_Test_Prediction = Log.predict(X_test)
Log_Train_Prediction = Log.predict(X_train)

# %% [markdown]
# #### Evaluating the Logistic regression's performance

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,roc_auc_score,roc_curve,f1_score,classification_report

# %%
print(f"Logistic_Regression's Accuracy_score_of_Test_prediction ",accuracy_score(Log_Test_Prediction,y_test)*100)
print(' '*20)
print('*'*20)
print(f"Logistic_Regression's Accuracy_score_of_Train_prediction ",accuracy_score(Log_Train_Prediction,y_train)*100)
print(' '*20)
print('*'*20)
print(f"Logistic_Regression's Confusion_Matrix_of_Test_prediction ",confusion_matrix(Log_Test_Prediction,y_test))
print(' '*20)
print('*'*20)
print(f"Logistic_Regression's Confusion_Matrix_of_Train_prediction",confusion_matrix(Log_Train_Prediction,y_train))
print(' '*20)
print('*'*20)
print(f"Logistic_Regression's F1 Score of Test_Prediction",f1_score(Log_Test_Prediction,y_test))
print(' '*20)
print('*'*20)
print(f"Logistic_Regression's F1 Score of Train_prediction",f1_score(Log_Train_Prediction,y_train))

print(' ' * 20 )
print(' ' * 20 )
print(' ' * 20 )
print(' ' * 20 )
print(' ' * 20 )

print('*'*20)

print(f"Logistic_Regression's Classification of Test_Prediction : "
      ,classification_report(Log_Test_Prediction,y_test))
print(' '*20)
print(' '*20)
print(' '*20)
print(' '*20)
print(' '*20)

print(f"Logistic_Regression's Classification of Train_Prediction : "
      ,classification_report(Log_Train_Prediction,y_train))
# Out:
# Logistic_Regression's Accuracy_score_of_Test_prediction  99.76028765481423
#
# ********************
# Logistic_Regression's Accuracy_score_of_Train_prediction  99.67029673294036
#
# ********************
# Logistic_Regression's Confusion_Matrix_of_Test_prediction  [[1280    3]
#  [   3 1217]]
#
# ********************
# Logistic_Regression's Confusion_Matrix_of_Train_prediction [[4959   19]
#  [  14 5017]]
#
# ********************
# Logistic_Regression's F1 Score of Test_Prediction 0.9975409836065574
#
# ********************
# Logistic_Regression's F1 Score of Train_prediction 0.9967219628489122
#
#
#
#
#
# ********************
# Logistic_Regression's Classification of Test_Prediction :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1283
#            1       1.00      1.00      1.00      1220
#
#     accuracy                           1.00      2503
#    macro avg       1.00      1.00      1.00      2503
# ...

# %%
## Better way to visualize the confusion matrix

# %%
cm_of_Test = confusion_matrix(Log_Test_Prediction,y_test)
cm_of_Train = confusion_matrix(Log_Train_Prediction,y_train)

# %%
plt.figure(figsize=(12,10))
sns.heatmap(cm_of_Test,annot=True,fmt='d',cmap='Blues',cbar=False,
           xticklabels=['Predicted 0' , 'Predicted 1'],
           yticklabels=['Actual 0 ', 'Actual 1'])
plt.xlabel('Prediction')
plt.ylabel('Actual')
plt.title('Confusion_Matrix')
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(cm_of_Train,annot=True,fmt='d',cmap='Greens',cbar=False,
           xticklabels=['Predicted 0 ', 'predicted 1'],
           yticklabels=['Actual 0 ', 'Actual 1'])

plt.xlabel('Prediction')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
